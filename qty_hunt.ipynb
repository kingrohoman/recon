# %% [markdown]
# ### Hunting for SKU variance in PO7370
#
# - 7370 is missing quantity exactly 2135
# - Suspicion was that these units existed in another PO but turns out it did not
# - Going to be looking for these quantities in NAFTA + SB by querying for the problems SKUs through each database

# %% [markdown]
# ### Connecting to SB database

# %%
from sqlalchemy import create_engine
import pandas as pd

# Replace with your actual server name and DB name if different
server_name = "DESKTOP-AB1234\\SQLEXPRESS"
database_name = "shipping_costs"

connection_string = (
    f"mssql+pyodbc://@{server_name}/{database_name}"
    "?driver=ODBC+Driver+17+for+SQL+Server"
    "&trusted_connection=yes"
)

engine = create_engine(connection_string)

# Example query
df = pd.read_sql("SELECT TOP 10 * FROM your_table", engine)
print(df.head())

# %% [markdown]
# ### Hunting in SB
#
# - To locate SKUs received during a certain period in SB db we are going to reference the POReceiveLine table:
